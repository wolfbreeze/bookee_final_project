# %%
from sportsreference.nfl.teams import Teams
import pandas as pd
teams = Teams()
DET = teams('DET')
DET_df=DET.dataframe
DET_df
# Out:
#     abbreviation  defensive_simple_rating_system  first_downs  \
# DET          DET                             0.4           87
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# DET                           6        4             4              2       1
#
#      margin_of_victory           name  ...  rush_yards  \
# DET                0.5  Detroit Lions  ...         482
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# DET                     3.9                  -0.6                  -1.1
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# DET          6           0.625     2   1550                   239
#
#      yards_per_play
# DET             5.7
#
# [1 rows x 39 columns]

# %%
MIA = teams('MIA')
MIA_df=MIA.dataframe

KAN = teams('KAN')
KAN_df=KAN.dataframe

RAV = teams('RAV')
RAV_df=RAV.dataframe

TAM = teams('TAM')
TAM_df=TAM.dataframe

NWE = teams('NWE')
NWE_df=NWE.dataframe

RAM = teams('RAM')
RAM_df=RAM.dataframe

PHI = teams('PHI')
PHI_df=PHI.dataframe

MIA = teams('MIA')
MIA_df=MIA.dataframe

DAL = teams('DAL')
DAL_df=DAL.dataframe

SEA = teams('SEA')
SEA_df=SEA.dataframe

SFO = teams('SFO')
SFO_df=SFO.dataframe

CAR = teams('CAR')
CAR_df=CAR.dataframe

CLT = teams('CLT')
CLT_df=CLT.dataframe

OTI = teams('OTI')
OTI_df=MIA.dataframe

SDG = teams('SDG')
SDG_df=SDG.dataframe

# %%
teams = Teams()
for teams in teams:
    print(teams.abbreviation)
# Out:
# KAN
# RAV
# TAM
# NWE
# RAM
# PHI
# DAL
# SEA
# DET
# SFO
# CAR
# CLT
# OTI
# SDG
# CLE
# NYG
# GNB
# JAX
# NOR
# MIN
# RAI
# HTX
# BUF
# PIT
# CRD
# ATL
# DEN
# CHI
# WAS
# CIN
# NYJ
# MIA

# %%
frames = [KAN_df,
RAV_df,
TAM_df,
NWE_df,
RAM_df,
PHI_df,
DAL_df,
SEA_df,
DET_df,
SFO_df,
CAR_df,
CLT_df,
OTI_df,
SDG_df]
combined_df = pd.concat(frames)
combined_df
# Out:
#     abbreviation  defensive_simple_rating_system  first_downs  \
# KAN          KAN                            -2.5          104
# RAV          RAV                            -3.6          110
# TAM          TAM                            -3.4           88
# NWE          NWE                            10.5           83
# RAM          RAM                            -1.6           98
# PHI          PHI                            -7.2           86
# DAL          DAL                             3.4           91
# SEA          SEA                            -2.9           84
# DET          DET                             0.4           87
# SFO          SFO                             5.0           70
# CAR          CAR                             6.6           81
# CLT          CLT                            -8.1           94
# MIA          MIA                           -16.7           53
# SDG          SDG                             1.5           92
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# KAN                          15        4             4              0       0
# RAV                           6        1             4              2       2
# TAM                           9        1             4              5       2
# NWE                           7        2             4              2       0
# RAM                          10        3             4              6       1
# PHI                           9        3             4              2       2
# DAL                           7        2             4              3       1
# SEA                           9        4             4              0       1
# DET                           6        4             4              2       1
# SFO                           7        4             3              4       0
# CAR                           6        7             4              1       2
# CLT                          13        2             4              2       2
# MIA                           7        2             4              7       4
# SDG                           8        3             4              2       2
#
#      margin_of_victory                  name  ...  rush_yards  \
# KAN               10.3    Kansas City Chiefs  ...         407
# RAV                8.8      Baltimore Ravens  ...         823
# TAM                1.5  Tampa Bay Buccaneers  ...         453
# NWE               23.8  New England Patriots  ...         365
# RAM                3.3      Los Angeles Rams  ...         399
# PHI                1.3   Philadelphia Eagles  ...         475
# DAL               12.8        Dallas Cowboys  ...         582
# SEA                3.5      Seattle Seahawks  ...         446
# DET                0.5         Detroit Lions  ...         482
# SFO               14.0   San Francisco 49ers  ...         525
# CAR                3.8     Carolina Panthers  ...         433
# CLT               -2.0    Indianapolis Colts  ...         530
# MIA              -34.3        Miami Dolphins  ...         207
# SDG                4.0  Los Angeles Chargers  ...         414
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# KAN                     4.2                   9.1                  -1.1
# RAV                     5.9                   2.5                  -6.2
# TAM                     3.8                   7.4                   5.9
# NWE                     3.2                  16.8                  -7.0
# RAM                     4.1                   7.2                   4.0
# PHI                     4.1                  -2.3                  -3.6
# DAL                     4.9                   1.8                 -10.9
# SEA                     4.0                  -0.2                  -3.7
# DET                     3.9                  -0.6                  -1.1
# SFO                     4.6                  13.0                  -1.0
# CAR                     4.3                   5.9                   2.2
# CLT                     4.6                  -4.7                  -2.7
# MIA                     3.0                 -28.8                   5.4
# SDG                     4.3                  -4.2                  -8.2
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# KAN          4           1.000     4   1899                   251
# RAV          3           0.500     2   1930                   177
# TAM          6           0.500     2   1547                   282
# NWE          4           1.000     4   1449                   237
# RAM          9           0.750     3   1591                   263
# PHI          5           0.500     2   1431                   238
# DAL          5           0.750     3   1701                   278
# SEA          4           0.750     3   1511                   266
# DET          6           0.625     2   1550                   239
# SFO          8           1.000     3   1263                   233
# CAR          8           0.500     2   1405                   166
# CLT          4           0.500     2   1389                   149
# MIA          9           0.000     0    900                   174
# SDG          5           0.500     2   1615                   248
#
#      yards_per_play
# KAN             7.4
# RAV             6.7
# TAM             5.7
# NWE             5.4
# RAM             5.7
# PHI             5.3
# DAL             6.9
# SEA             5.9
# DET             5.7
# SFO             6.3
# CAR             5.4
# CLT             5.4
# MIA             4.0
# SDG             6.3
#
# [14 rows x 39 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-5ff1be9a38ed> in <module>
#       1 All = Teams()
# ----> 2 All_df=All.dataframe
#
# AttributeError: 'Teams' object has no attribute 'dataframe'
